# %%
#import required libraries

import seaborn as sn
import pandas as pd
import numpy as np
import random as rd
import statistics as st
import matplotlib.pyplot as plt
import sklearn as sk

# %%
path = "/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RAW DATA/diabetes.csv"
df_raw = pd.read_csv(path)

# %%
df_raw.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_raw.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
print("Number of Rows: {}\nNumber of Columns: {}".format(df_raw.shape[0], df_raw.shape[1]))
# Out:
# Number of Rows: 768
# Number of Columns: 9

# %%
#check if we have any null values in the data

df_raw.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#data looks clean.so, we make a copy of clean data in seperate folder

df_raw.to_csv('/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/CLEAN DATA/clean_data.csv')

# %%
#selecting 25 random observations
#seed = random.seed(7)

df_getsample_frompopulation= df_raw.sample(n= 25, random_state= 45)

# %%
#extracting the first five rows of sample

df_getsample_frompopulation.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 195            5      158             84             41      210  39.4
# 51             1      101             50             15       36  24.2
# 66             0      109             88             30        0  32.5
# 437            5      147             75              0        0  29.9
# 665            1      112             80             45      132  34.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 195                     0.395   29        1
# 51                      0.526   26        0
# 66                      0.855   38        1
# 437                     0.434   28        0
# 665                     0.217   24        0

# %%
#finding the mean Glucose of the sample

mean_glucose_sample = st.mean(df_getsample_frompopulation.loc[:,"Glucose"])
print(mean_glucose_sample)
# Out:
# 119.24

# %%
#finding the max Glucose of the sample

max_glucose_sample = max(df_getsample_frompopulation.loc[:,"Glucose"])
print(max_glucose_sample)
# Out:
# 193

# %%
#finding the mean Glucose of the population

mean_glucose_population = st.mean(df_raw.loc[:,"Glucose"])
print(mean_glucose_population)
# Out:
# 120.89453125

# %%
#finding the max Glucose of the population

max_glucose_population = max(df_raw.loc[:,"Glucose"])
print(max_glucose_population)
# Out:
# 199

# %%
# let us create a dictonary which stores the mean values of sample and population

class mean_dictionary(dict):
    
    def __init__(self):
        self = dict()
    
    def add(self, key, value):
        self[key] = value
 
 
# Main Function
dict_mean = mean_dictionary()
 
dict_mean.add('mean_sample', mean_glucose_sample)
dict_mean.add('mean_population', mean_glucose_population)
 
print(dict_mean)


## Saving the results into results folder

result_save = open("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/A/dict_mean.txt","w")

# write file
result_save.write(str(dict_mean))

# close file
result_save.close()
# Out:
# {'mean_sample': 119.24, 'mean_population': 120.89453125}

# %%
# let us create a dictonary which stores the max values of sample and population

class max_dictionary(dict):
    
    def __init__(self):
        self = dict()
    
    def add(self, key, value):
        self[key] = value
 
 
# Main Function
dict_max = max_dictionary()
 
dict_max.add('max_sample', max_glucose_sample)
dict_max.add('max_population', max_glucose_population)
 
print(dict_max)


## Saving the results into results folder

result_save = open("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/A/dict_max.txt","w")

# write file
result_save.write(str(dict_max))

# close file
result_save.close()
# Out:
# {'max_sample': 193, 'max_population': 199}

# %%
#creating the line graph for sample mean vs population mean 

mean_values = list(dict_mean.keys())
values = list(dict_mean.values())
 
# creating the line plot

plt.plot(mean_values, values, color ='red')
 
plt.xlabel("sample vs population mean")
plt.ylabel("mean values")
plt.title("MEANS")


plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/A/mean_lineimage.jpeg")

plt.show()

# %%
#creating the pie graph for sample mean vs population mean 

mycolors = ["r", "m"]
plt.pie(values, labels = mean_values, autopct='%1.1f%%', startangle=180,colors = mycolors)
plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/A/mean_pieimage.jpeg")

# %%
#creating the line graph for sample max vs population max 


max_values = list(dict_max.keys())
values = list(dict_max.values())
  
fig = plt.figure(figsize = (4, 5))
 
# creating the line plot
plt.plot(max_values, values, color ='blue', linestyle = 'dashed')
 
plt.xlabel("sample_max vs population_max")
plt.ylabel("highest values")
plt.title("highest value measurement")

plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/A/max_lineimage.jpeg")



plt.show()

# %%
#creating the pie graph for sample max vs population max

mycolors = ["r", "g"]
plt.pie(values, labels = max_values , autopct='%1.1f%%', startangle=270,colors = mycolors)
plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/A/max_pieimage.jpeg")

# %%
#98th percentile of sample data

sample_percentile = np.percentile(df_getsample_frompopulation.loc[:,"BMI"], 98)
print(sample_percentile)
# Out:
# 47.78

# %%
#98th percentile of population data

population_percentile = np.percentile(df_raw.loc[:,"BMI"], 98)
print(population_percentile)
# Out:
# 47.52599999999996

# %%
# let us create a dictonary which stores the percentile values of sample and population

class percentile_dictionary(dict):
    
    def __init__(self):
        self = dict()
    
    def add(self, key, value):
        self[key] = value
 
 
# Main Function
dict_percentile = percentile_dictionary()
 
dict_percentile.add('sample_percentile', sample_percentile)
dict_percentile.add('population_percentile', population_percentile)
 
print(dict_percentile)


## Saving the results into results folder

result_save = open("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/B/dict_percentile.txt","w")

# write file
result_save.write(str(dict_percentile))

# close file
result_save.close()
# Out:
# {'sample_percentile': 47.78, 'population_percentile': 47.52599999999996}

# %%
#creating the line graph for sample vs population percentile 

percentile_values = list(dict_percentile.keys())
values = list(dict_percentile.values())
  
fig = plt.figure(figsize = (4, 5))
 
# creating the line plot
plt.plot(percentile_values, values, color ='red')
 
plt.xlabel("sample vs population")
plt.ylabel("percentile values")
plt.title("percentile value measurement")

plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/B/percentile_lineimage.jpeg")


plt.show()

# %%
#creating the pie graph for sample vs population percentile

plt.pie(values, labels = percentile_values , autopct='%1.1f%%', startangle=90)
plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/B/percentile_pieimage.jpeg")

# %%
#Using bootstrap (replace= True), created 500 samples (of 150 observation each) from the population(raw_data) 

boot = sk.utils.resample(df_raw, replace=True, n_samples=500, random_state=150)

print(boot)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 228            4      197             70             39      744  36.7
# 442            4      117             64             27      120  33.2
# 507            1      130             60             23      170  28.6
# 25            10      125             70             26      115  31.1
# 496            5      110             68              0        0  26.0
# ..           ...      ...            ...            ...      ...   ...
# 732            2      174             88             37      120  44.5
# 514            3       99             54             19       86  25.6
# 750            4      136             70              0        0  31.2
# 364            4      147             74             25      293  34.9
# 485            0      135             68             42      250  42.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 228                     2.329   31        0
# 442                     0.230   24        0
# 507                     0.692   21        0
# 25                      0.205   41        1
# 496                     0.292   30        0
# ..                        ...  ...      ...
# 732                     0.646   24        1
# 514                     0.154   24        0
# 750                     1.182   22        1
# 364                     0.385   30        0
# 485                     0.365   24        1
#
# [500 rows x 9 columns]

# %%
#find the mean BloodPressure of the bootstrapsample

mean_bootBloodPressure = st.mean(boot.loc[:,"BloodPressure"])
print(mean_bootBloodPressure)
# Out:
# 68.348

# %%
#find the std BloodPressure of the bootstrapsample

std_bootBloodPressure = st.stdev(boot.loc[:,"BloodPressure"])
print(std_bootBloodPressure)
# Out:
# 20.10729974427228

# %%
#find the percentile BloodPressure of the bootstrapsample

percentile_bootBloodPressure = np.percentile(boot.loc[:,"BloodPressure"], 98)
print(percentile_bootBloodPressure)
# Out:
# 96.0

# %%
#find the mean BloodPressure of the population

mean_rawBloodPressure = st.mean(df_raw.loc[:,"BloodPressure"])
print(mean_rawBloodPressure)
# Out:
# 69.10546875

# %%
#find the std BloodPressure of the population

std_rawBloodPressure = st.stdev(df_raw.loc[:,"BloodPressure"])
print(std_rawBloodPressure)
# Out:
# 19.355807170644777

# %%
#find the percentile BloodPressure of the population

percentile_rawBloodPressure = np.percentile(df_raw.loc[:,"BloodPressure"], 98)
print(percentile_rawBloodPressure)
# Out:
# 99.31999999999994

# %%
# let us create a dictonary which stores the mean values of bootsample and population 

class Bootmean_dictionary(dict):
    
    def __init__(self):
        self = dict()
    
    def add(self, key, value):
        self[key] = value
 
 
# Main Function
dict_Bootmean = Bootmean_dictionary()
 
dict_Bootmean.add('mean_Bootsample', mean_bootBloodPressure)
dict_Bootmean.add('mean_population', mean_rawBloodPressure)
 
print(dict_Bootmean)

## Saving the results into results folder

result_save = open("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/dict_Bootmean.txt","w")

# write file
result_save.write(str(dict_Bootmean))

# close file
result_save.close()
# Out:
# {'mean_Bootsample': 68.348, 'mean_population': 69.10546875}

# %%
#creating the line graph for sample_boot mean vs population mean


Bootmean_values = list(dict_Bootmean.keys())
values = list(dict_Bootmean.values())
  
fig = plt.figure(figsize = (4, 5))
 
# creating the line plot
plt.plot(Bootmean_values, values, color ='orange')
 
plt.xlabel("Bootstrapsample vs population")
plt.ylabel("mean values")
plt.title("mean value measurement")

plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/bootmean_lineimage.jpeg")


plt.show()

# %%
#creating the pie graph for sample vs population mean

mycolors = ["r", "black"]
plt.pie(values, labels = Bootmean_values, startangle=90, colors=mycolors)
plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/bootmean_pieimage.jpeg")

# %%
# let us create a dictonary which stores the std values of sample and population 

class Bootstd_dictionary(dict):
    
    def __init__(self):
        self = dict()
    
    def add(self, key, value):
        self[key] = value
 
 
# Main Function
dict_Bootstd = Bootstd_dictionary()
 
dict_Bootstd.add('std_Bootsample', std_bootBloodPressure)
dict_Bootstd.add('std_population', std_rawBloodPressure)
 
print(dict_Bootstd)

## Saving the results into results folder

result_save = open("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/dict_Bootstd.txt","w")

# write file
result_save.write(str(dict_Bootstd))

# close file
result_save.close()
# Out:
# {'std_Bootsample': 20.10729974427228, 'std_population': 19.355807170644777}

# %%
#creating the line graph for sample vs population std

Bootstd_values = list(dict_Bootstd.keys())
values = list(dict_Bootstd.values())
  
fig = plt.figure(figsize = (4, 5))
 
# creating the line plot
plt.plot(Bootstd_values, values, color ='black')
 
plt.xlabel("Bootstrap sample vs population")
plt.ylabel("SD values")
plt.title("SD value measurement")

plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/bootstd_lineimage.jpeg")


plt.show()

# %%
#creating the pie graph for sample vs population std

mycolors=["c","g"]
plt.pie(values, labels = Bootstd_values , autopct='%1.1f%%', shadow=True, startangle=90,colors=mycolors)
plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/bootstd_pieimage.jpeg")

# %%
# let us create a dictonary which stores the percentile values of sample and population 

class Bootpercentile_dictionary(dict):
    
    def __init__(self):
        self = dict()
    
    def add(self, key, value):
        self[key] = value
 
 
# Main Function
dict_Bootpercentile = Bootpercentile_dictionary()
 
dict_Bootpercentile.add('percentile_Bootsample', percentile_bootBloodPressure)
dict_Bootpercentile.add('percentile_population', percentile_rawBloodPressure)
 
print(dict_Bootpercentile)

## Saving the results into results folder

result_save = open("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/dict_Bootpercentile.txt","w")

# write file
result_save.write(str(dict_Bootstd))

# close file
result_save.close()
# Out:
# {'percentile_Bootsample': 96.0, 'percentile_population': 99.31999999999994}

# %%
#creating the line graph for sample vs population percentile

Bootpercentile_values = list(dict_Bootpercentile.keys())
values = list(dict_Bootpercentile.values())
  
fig = plt.figure(figsize = (4, 5))
 
# creating the line plot
plt.plot(Bootpercentile_values, values, color ='purple')
 
plt.xlabel("Bootstrap sample vs population")
plt.ylabel("Percentile values")
plt.title("percentile value measurement")

plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/bootpercentile_lineimage.jpeg")


plt.show()

# %%
#creating the pie graph for sample vs population percentile

mycolors = ["black", "hotpink"]
plt.pie(values, labels = Bootpercentile_values, autopct='%1.1f%%', shadow=True, startangle=90,colors=mycolors)
plt.savefig("/Users/vd/Desktop/Spring 2023/PDS/ASSIGNMENT-2/RESULTS/C/bootpercentile_pieimage.jpeg")
